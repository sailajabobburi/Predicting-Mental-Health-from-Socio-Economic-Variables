# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tabulate import tabulate
import utils
# Out:
# Data loaded successfully.

# %%
#Reading the  data file into the environment
data_df=utils.read_csv_data("Data/raw/data.csv")
# Out:
# Data loaded successfully.

# %%
utils.summarize_dataframe_columns(data_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 utils.summarize_dataframe_columns(data_df)
#
# AttributeError: module 'utils' has no attribute 'summarize_dataframe_columns'

# %%
#starategies handling missing gender specific data

#Method 1:Drop these columns for now

def drop_columns(df, columns):
    return df.drop(columns, axis=1)

gender_columns=['sec_amenorrhea1','ever_preg1','miscarried1','total_fertility1','childmortality1','man_decides1','refuse_sex1','wife_expresses1','wife_decides1','wife_tolerates1','beat_refusingsex1','polygamous1']

df_new=drop_columns(data_df,gender_columns)

# %%
analyze_dataframe(df_new)
# Out:
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | Column Name          | Data Type   |   No of Null Values |   Percentage of Null Values |   No of Unique Values |
# +======================+=============+=====================+=============================+=======================+
# | sleeping_time1       | float64     |                2689 |                  81.6581    |                    43 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | yr_elec_ntnlgrid1    | float64     |                2177 |                  66.1099    |                    40 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | elec_com_cntd1       | float64     |                2161 |                  65.6241    |                    26 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | elec_com_days1       | float64     |                2144 |                  65.1078    |                    24 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | emp_work_stat1       | float64     |                1864 |                  56.6049    |                     6 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | son_preference1      | float64     |                1542 |                  46.8266    |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | elec_ntnlgrid1       | float64     |                1291 |                  39.2044    |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | accra_primsec1       | float64     |                 918 |                  27.8773    |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | physicalabuse1       | float64     |                 837 |                  25.4176    |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | emotionalabuse1      | float64     |                 836 |                  25.3872    |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | rur_primsec1         | float64     |                 801 |                  24.3243    |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | age_married1         | float64     |                 580 |                  17.6131    |                    27 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | workdays_per_week1   | float64     |                 524 |                  15.9125    |                     7 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | radio_listening1     | float64     |                 301 |                   9.1406    |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | big5open_score1      | float64     |                 263 |                   7.98664   |                    39 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | big5consc_score1     | float64     |                 263 |                   7.98664   |                    28 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | big5extrav_score1    | float64     |                 263 |                   7.98664   |                    32 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | big5agreeable_score1 | float64     |                 263 |                   7.98664   |                    31 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | big5neurotic_score1  | float64     |                 263 |                   7.98664   |                    33 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | educ_mother1         | float64     |                 253 |                   7.68296   |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | sick_care1           | float64     |                 232 |                   7.04525   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kids_care1           | float64     |                 231 |                   7.01488   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | collecting_firewood1 | float64     |                 226 |                   6.86304   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | fetching_water1      | float64     |                 226 |                   6.86304   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | errands1             | float64     |                 226 |                   6.86304   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | time_cleaning1       | float64     |                 226 |                   6.86304   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | elderly_care1        | float64     |                 226 |                   6.86304   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | time_clothes1        | float64     |                 223 |                   6.77194   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | time_shopping1       | float64     |                 222 |                   6.74157   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | dish_washing1        | float64     |                 221 |                   6.71121   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | reading1             | float64     |                 218 |                   6.6201    |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | time_cooking1        | float64     |                 216 |                   6.55937   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | tv_watching1         | float64     |                 214 |                   6.49863   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | educ_father1         | float64     |                 209 |                   6.3468    |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | early_sex1           | float64     |                 174 |                   5.28394   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | work_mother1         | float64     |                 162 |                   4.91953   |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | housing_type1        | float64     |                 108 |                   3.27968   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | bmi1                 | float64     |                 106 |                   3.21895   |                  1392 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | obese1               | float64     |                 106 |                   3.21895   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | happy_life1          | float64     |                  86 |                   2.6116    |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | labor_community1     | float64     |                  66 |                   2.00425   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | height1              | float64     |                  48 |                   1.45764   |                   163 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | work_father1         | float64     |                  48 |                   1.45764   |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | problem_community1   | float64     |                  42 |                   1.27543   |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | altruism1            | float64     |                  37 |                   1.1236    |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | shared_dwelling1     | float64     |                  32 |                   0.971758  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | alert_community1     | float64     |                  30 |                   0.911023  |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | partner_control1     | float64     |                  27 |                   0.819921  |                     5 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | trusted_community1   | float64     |                  24 |                   0.728819  |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | helpful_community1   | float64     |                  24 |                   0.728819  |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | tobaccouse_ever1     | float64     |                  23 |                   0.698451  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | still_smokes1        | float64     |                  23 |                   0.698451  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | farmtools_yn1        | float64     |                  18 |                   0.546614  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | borrow_yn1           | float64     |                  16 |                   0.485879  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | lend_yn1             | float64     |                  16 |                   0.485879  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | intrans_yn1          | float64     |                  16 |                   0.485879  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | outtrans_yn1         | float64     |                  16 |                   0.485879  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | savings_yn1          | float64     |                  16 |                   0.485879  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | drinking_water_w11   | float64     |                  14 |                   0.425144  |                     4 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | emp_stat1            | float64     |                  13 |                   0.394777  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | unemployed_dur1      | float64     |                  13 |                   0.394777  |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | unemployed1          | float64     |                  13 |                   0.394777  |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | healthstatus1        | float64     |                   9 |                   0.273307  |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | wealth1              | float64     |                   6 |                   0.182205  |                     5 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | rel_stat1            | float64     |                   4 |                   0.12147   |                     4 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | nhis_valid1          | float64     |                   4 |                   0.12147   |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | prop_hh_nhis1        | float64     |                   4 |                   0.12147   |                    35 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | ladderlife_com1      | float64     |                   4 |                   0.12147   |                    10 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | educ1                | float64     |                   3 |                   0.0911023 |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | ladderlife_gh1       | float64     |                   3 |                   0.0911023 |                    10 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | k61                  | float64     |                   1 |                   0.0303674 |                    23 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kessler_dummy2       | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kessler_dummy3       | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kessler_dummy4       | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | exit_entry_w1w2      | int64       |                   0 |                   0         |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | exit_entry_w1w3      | int64       |                   0 |                   0         |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | exit_entry_w1w4      | int64       |                   0 |                   0         |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | exit_entry_w2w3      | int64       |                   0 |                   0         |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | exit_entry_w3w4      | int64       |                   0 |                   0         |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kessler_dummy1       | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | female1              | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | age_yrs1             | int64       |                   0 |                   0         |                    53 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | age_sq_1001          | float64     |                   0 |                   0         |                    53 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | hh_head1             | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | maritalstatus1       | int64       |                   0 |                   0         |                     3 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | akan1                | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | hh_size1             | int64       |                   0 |                   0         |                    19 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | prop_U181            | float64     |                   0 |                   0         |                    35 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | prop_adult1          | float64     |                   0 |                   0         |                    35 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | prop_E60_691         | float64     |                   0 |                   0         |                    21 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | prop_70plus1         | float64     |                   0 |                   0         |                    12 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | ill_psttwo1          | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | prop_ill_psttwo1     | float64     |                   0 |                   0         |                    34 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | improved_tf_w11      | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | urban1               | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | region_old1          | int64       |                   0 |                   0         |                    10 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | north1               | int64       |                   0 |                   0         |                     2 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | k62                  | int64       |                   0 |                   0         |                    22 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | k63                  | int64       |                   0 |                   0         |                    22 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | k64                  | int64       |                   0 |                   0         |                    25 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kessler1             | int64       |                   0 |                   0         |                    35 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kessler2             | int64       |                   0 |                   0         |                    31 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kessler3             | int64       |                   0 |                   0         |                    33 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | kessler4             | int64       |                   0 |                   0         |                    37 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
# | Unique_ID            | int64       |                   0 |                   0         |                  3293 |
# +----------------------+-------------+---------------------+-----------------------------+-----------------------+
#            Column Name Data Type  No of Null Values  \
# 0       sleeping_time1   float64               2689
# 1    yr_elec_ntnlgrid1   float64               2177
# 2       elec_com_cntd1   float64               2161
# 3       elec_com_days1   float64               2144
# 4       emp_work_stat1   float64               1864
# ..                 ...       ...                ...
# 100           kessler1     int64                  0
# 101           kessler2     int64                  0
# 102           kessler3     int64                  0
# 103           kessler4     int64                  0
# 104          Unique_ID     int64                  0
#
#      Percentage of Null Values  No of Unique Values
# 0                    81.658063                   43
# 1                    66.109930                   40
# 2                    65.624051                   26
# 3                    65.107804                   24
# 4                    56.604920                    6
# ..                         ...                  ...
# 100                   0.000000                   35
# 101                   0.000000                   31
# 102                   0.000000                   33
# 103                   0.000000                   37
# 104                   0.000000                 3293
#
# [105 rows x 5 columns]

# %%
continuous_features=['age_yrs1','age_sq_100','age_married','prop_U181','prop_adult','prop_E60_691','prop_70plus1','prop_ill_psttwo1','bmi1','height1','prop_hh_nhis1','sleeping_time1',]
